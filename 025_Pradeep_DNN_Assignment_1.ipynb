# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeepjha88/Logistic-regression/blob/main/025_Pradeep_DNN_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRN**:                  ______________________________<br>
# **Name of Student**:      ______________________________<br>
# **Date of Submission**:   ______________________________<br>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>e-DAI May 2021| Deep Neural Network</h1>
#     <h2>Assignment 1</h2>
# </div>
#
# <div class="alert alert-block alert-warning" style="font-family: Arial; font-size:1.2em;">
# <h2>Instructions:</h2>
#    <ol>
#        <li>Read these instructions carefully.</li>
#        <li>Do not <b>REMOVE</b> any cell.</li>
#        <li>Put comments to explain your code.</li>
#        <li>If your code fails in compilation, submission will be <b><i>rejected</i></b>. Therefore your code shall be free of compilation errors.</li>
#        <li>If you delete any cell, your submission may become invalid.</li>
#        <li>Your code shall be within the lines marked for the purpose.</li>
#        <li>You should be able to attempt all questions if you are regular in the class and submission of assignments.</li>
#        <li>Do not panic on reading a question if you do not know the answer. Attempt the question logically. Explain your steps in details.</li>
#        <li>Upload the file to the designated location by renaming as <strong>PRN_{PRN #}_DNN_Assignment_1.ipynb</strong></li>
#     </ol>
#     Your code shall be between lines marked thus.
# </div>
#
# >`#### START YOUR CODE`
#
# >`#### END YOUR CODE`

# %% [markdown]
# ## 1. Import Statements

# %%
# Lets import some libraries
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from sklearn import datasets

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, confusion_matrix

# %matplotlib inline

# %% [markdown]
# ## 2. Some global Parameters

# %%
# Parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (12, 9),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

plt.rcParams.update(params)

# Global Parameters
RANDOM_STATE = 24

NUM_SAMPLES = 5000

NOISE = 0.1

TEST_SIZE = 0.2

EPOCHS = 1000

inpDir = '../input' # It is recomended to keep inputs and outputs in separate directories
outDir = '../output'

# %% [markdown]
# ## 3. DataSet
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# Use Sklearn's dataset generator and load breast cancer dataset.
# </div>

# %%
# data Loaded
dataset = datasets.load_breast_cancer()
X = dataset.data
y = dataset.target

# %% [markdown]
# # 4. Implementation

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# <h3> Step 1: </h3>
# Investigate what is there in the data
# </div>

# %%
#### START YOUR CODE

#### END YOUR CODE

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# <h3> Step 2: </h3>
# Print unique values of the target or 'y'
# </div>

# %%
#### START YOUR CODE

#### END YOUR CODE

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# <h3> Step 3: </h3>
# Plotting first two columns.
# </div>

# %%
plt.scatter ( X[:, 0], X[:,1],
             marker= '*',
             s=50,
             c=y,
             cmap=plt.cm.Spectral);
plt.grid();
plt.xlabel('mean radius')
plt.ylabel('mean texture')
plt.title("Scatter Plot");

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# <h3> Step 4: </h3>
# Based on what you have seen till now, what other plots you may want to use?
# </div>

# %%
#### START YOUR CODE

#### END YOUR CODE

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# <h3> Step 5: </h3>
# Split data in Test and Train buckets.
# </div>

# %%
#### START YOUR CODE

#### END YOUR CODE

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# <h3> Step 6: </h3>
# Remember MP Neurons only take binary data.<br>
#     <b>Hint:</b> Use pandas pd.cut to binarize the data
# </div>

# %%
#### START YOUR CODE

#### END YOUR CODE

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-family: Arial; font-size:1.1em;">
# <h3> Step 7: </h3>
#     Code model<br><br>
# <b>Hint:</b>
#     <ol>
# <li>Prepare sum by rows.</li>
# <li>If sum is greater than threshold, mark 1, else 0.</li>
# <li>Check accuracy.</li>
# <li>Iterate between possible valid values, to get best accuracy.</li>
# <li>Sklearn accuracy_score is available for your convenience.</li>
# </ol>
